# %% [markdown]
# <a href="https://colab.research.google.com/github/hersh11/CV/blob/main/pattern_exp_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab Exp 1: Data Visualization using Python
# ## AIM: To visualize data using Pie charts and scatter plots
# ## Procedure: In this experiment, we visualize data and datasets using various chart options and plots option in Python and also obtain distribution of features of data and to obtain summary of the datasets.

# %% [markdown]
# ## The following Datasets are used in the experiments:
# ## 1. lin_sep.csv: a linearly separable dataset consisting of synthetically generated 2-dimensional data of 3 classes. The classes are linearly separable i.e., they can be separated using  lines.
# ## 2. ring.csv: A synthetically generated dataset that consists of 2-Dimensional data of three classes. The classes are non-liearly separable i.e. the classes are not separable with a linear surface.
# ## 3. spiral.csv: A synthetically generated dataset that consists of 2-Dimensional data of two classes. The classes are non-liearly separable i.e. the classes are not separable with a linear surface.
# ## 4. loan_data.csv: A real-world dataset that consists of financial information related to loan applications used for credit risk analysis and classification tasks.
# ## 5. iris2.csv: A classic dataset in machine learning with features of the iris flowers widely used for classification and pattern recognition..

# %%
#Import the required libraries in Python
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly

# %%
import matplotlib.pyplot as plt
x = [35, 20, 30, 40, 50, 30]
y = ['Apple', 'Banana', 'Grapes', 'Orange', 'PineApple', 'Dragon Fruit']
plt.title('Pie Chart')
plt.pie(x, labels=y)
plt.show()

# %%
df = pd.read_csv("/content/iris2.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ## Box Plots

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white", color_codes=True)
import warnings # current version of seaborn generates a bunch of warnings that we'll ignore
warnings.filterwarnings("ignore")

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

# %%
# We can look at an individual feature in Seaborn through a boxplot
sns.boxplot(x="Species", y="PetalLengthCm", data=df)
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
# One way we can extend this plot is adding a layer of individual points on top of
# it through Seaborn's striplot

# We'll use jitter=True so that all the points don't fall in single vertical lines
# above the species
# Saving the resulting axes as ax each time causes the resulting plot to be shown
# on top of the previous axes
ax = sns.boxplot(x="Species", y="PetalLengthCm", data=df)
ax = sns.stripplot(x="Species", y="PetalLengthCm", data=df, jitter=True, edgecolor="gray")

# %% [markdown]
# ## Violin Plot

# %%
# A violin plot combines the benefits of the previous two plots and simplifies them
# Denser regions of the data are fatter, and sparser thiner in a violin plot
sns.violinplot(x="Species", y="PetalLengthCm", data=df)
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %% [markdown]
# # Another useful seaborn plot is a hybrid plot called pairplot, which shows the bivariate relation between each pair of features. Lets see the same

# %%
# From the pairplot, we'll see that the Iris-setosa species is separataed from the other
# two across all feature combinations
sns.pairplot(df.drop("Id", axis=1), hue="Species", size=3)

# %% [markdown]
# ## Plotting Distribution of Features

# %%
# Visualize the distribution of the first few variables
for column in df.columns[1:5]:  # Adjust the range as needed
    plt.figure(figsize=(5, 3))
    sns.histplot(df[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.show()

# %% [markdown]
# ## Scatter Plots

# %%
y = df['Species']
X = pd.read_csv('iris2.csv', usecols=['SepalWidthCm', 'SepalLengthCm'])
len(y)
len(X)
# Out:
# 150

# %%
# three different scatter series so the class labels in the legend are distinct
plt.scatter(X[y=='Iris-setosa']['SepalWidthCm'], X[y=='Iris-setosa']['SepalLengthCm'], label='Iris-setosa', c='red')
plt.scatter(X[y=='Iris-versicolor']['SepalWidthCm'], X[y=='Iris-versicolor']['SepalLengthCm'], label='Iris-versicolor', c='blue')
plt.scatter(X[y=='Iris-virginica']['SepalWidthCm'], X[y=='Iris-virginica']['SepalLengthCm'], label='Iris-virginica', c='green')

# Prettify the graph
plt.legend()
plt.xlabel('SepalWidthCm')
plt.ylabel('SepalLengthCm')

# display
plt.show()

# %% [markdown]
# ## Scatter plots with petal.length and petal.width as features

# %%
y = df['Species']
X = pd.read_csv('iris2.csv', usecols=['PetalWidthCm', 'PetalLengthCm'])

# %%
# three different scatter series so the class labels in the legend are distinct
plt.scatter(X[y=='Iris-setosa']['PetalWidthCm'], X[y=='Iris-setosa']['PetalLengthCm'], label='Iris-setosa', c='red')
plt.scatter(X[y=='Iris-versicolor']['PetalWidthCm'], X[y=='Iris-versicolor']['PetalLengthCm'], label='Iris-versicolor', c='blue')
plt.scatter(X[y=='Iris-virginica']['PetalWidthCm'], X[y=='Iris-virginica']['PetalLengthCm'], label='Iris-virginica', c='green')

# Prettify the graph
plt.legend()
plt.xlabel('PetalWidthCm')
plt.ylabel('PetalLengthCm')

# display
plt.show()

# %% [markdown]
# ## Experiment with Loan_data

# %%
import pandas as pd
df = pd.read_csv('/content/loan_data.csv')
df.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df,x='purpose',hue='not.fully.paid')
plt.xticks(rotation=45, ha='right');

# %%
plt.figure()
plt.scatter(df['fico'], df['int.rate'], color='blue', alpha=0.6)
plt.xlabel('FICO Score')
plt.ylabel('Interest Rate')
plt.title('FICO Score vs Interest Rate')
plt.show()

# %%
plt.figure()
plt.scatter(df['installment'], df['log.annual.inc'], color='orange', alpha=0.6)
plt.xlabel('Installment Amount')
plt.ylabel('Log Annual Income')
plt.title('Installment vs Log Annual Income')
plt.show()

# %% [markdown]
# ## Experiment with tips dataset

# %%
# import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# to ignore the warnings
from warnings import filterwarnings

# load the dataset
df = sns.load_dataset('tips')

# the first five entries of the dataset
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# set the background style of the plot
sns.set_style('whitegrid')
sns.distplot(df['total_bill'], kde = False, color ='red', bins = 30)
# Out:
# <Axes: xlabel='total_bill'>

# %%
plt.figure()
sns.stripplot(x='sex', y='tip', data=df, jitter=True, palette=['blue', 'red'])
plt.xlabel('Gender')
plt.ylabel('Tip Amount')
plt.title('Individual Tips: Male vs Female')
plt.show()

# %%
plt.figure()
sns.violinplot(x='sex', y='tip', data=df, palette=['lightblue', 'pink'])
plt.xlabel('Gender')
plt.ylabel('Tip Amount')
plt.title('Tips by Gender (Male vs Female)')
plt.show()

# %%
import pandas as pd
data = pd.read_csv('/content/iris2.csv')
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
len(y)
len(X)
# Out:
# 150

# %% [markdown]
# # Experiment with synthetically generated datasets . the datasets are 2 dimensional features

# %%
import pandas as pd
data = pd.read_csv('/content/lin_sep.csv')
data.head()
# Out:
#    Id       f1       f2  class
# 0   1  0.96367  1.03590      1
# 1   2  0.46145 -0.48360      1
# 2   3 -0.94735  0.56562      1
# 3   4  1.84300  0.14423      1
# 4   5  1.28290  1.03350      1

# %%
y = data['class']
X = pd.read_csv('lin_sep.csv', usecols=['f1', 'f2'])

# %%
# three different scatter series so the class labels in the legend are distinct
plt.scatter(X[y==1]['f1'], X[y==1]['f2'], label='class1', c='red')
plt.scatter(X[y==2]['f1'], X[y==2]['f2'], label='class2', c='blue')
plt.scatter(X[y==3]['f1'], X[y==3]['f2'], label='class3', c='green')

# Prettify the graph
plt.legend()
plt.xlabel('f1')
plt.ylabel('f2')

# display
plt.show()

# %%
import pandas as pd
data = pd.read_csv('/content/ring.csv')
data.head()
# Out:
#          f1       f2  class
# 0 -0.326490  0.34617      1
# 1  0.701720  0.30700      1
# 2  0.223670 -0.62131      1
# 3 -0.012665  0.73175      1
# 4  0.563610  0.42704      1

# %%
y = data['class']
X = pd.read_csv('ring.csv', usecols=['f1', 'f2'])

# %%
# three different scatter series so the class labels in the legend are distinct
plt.scatter(X[y==1]['f1'], X[y==1]['f2'], label='class1', c='red')
plt.scatter(X[y==2]['f1'], X[y==2]['f2'], label='class2', c='blue')
plt.scatter(X[y==3]['f1'], X[y==3]['f2'], label='class3', c='green')

# Prettify the graph
plt.legend()
plt.xlabel('f1')
plt.ylabel('f2')

# display
plt.show()

# %%
import pandas as pd
data = pd.read_csv('/content/spiral.csv')
data.head()
# Out:
#         f1       f2  class
# 0  7.57170 -8.75630      1
# 1 -8.96290  0.45906      1
# 2  9.44540 -7.17010      1
# 3  0.19187  2.21110      1
# 4 -8.80770 -1.54800      1

# %%
y = data['class']
X = pd.read_csv('spiral.csv', usecols=['f1', 'f2'])

# %%
# three different scatter series so the class labels in the legend are distinct
plt.scatter(X[y==1]['f1'], X[y==1]['f2'], label='class1', c='red')
plt.scatter(X[y==2]['f1'], X[y==2]['f2'], label='class2', c='blue')
#plt.scatter(X[y==3]['f1'], X[y==3]['f2'], label='class3', c='lightgreen')

# Prettify the graph
plt.legend()
plt.xlabel('f1')
plt.ylabel('f2')

# display
plt.show()

# %%
#two moons dataset
from sklearn.datasets import make_moons
x_data, y_data = make_moons(n_samples=1000, noise=0.1, random_state=42)

# %%
class_colors = ["red","blue"]
for i in range(len(np.unique(y_data))):
  plt.scatter(x_data[y_data == i,0],
              x_data[y_data == i,1],
              color = class_colors[i],
              alpha= 0.2,
              label="Class " + str(i))
  plt.grid(alpha=0.2)
  plt.legend()
  plt.title("Two Moons Dataset")
  plt.show()

# %% [markdown]
# # Outcomes
# ## 1. Basic of python programming have been studied.
# ## 2. Common Python libraries are introduced, and their usage is learned
# ## 3. Common Plot commands for Pie charts, box plots, and scatter plots for 2D datasets are experimented with.
# ## 4. Data visualization commands such as head(), describe(), and their usage are familiarized.
# ## 5. Loading .csv files and manipulating such files are learned.
